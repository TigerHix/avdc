# %%
import math
import torch
import roma

# %%
def euler_xyz_to_zxy(euler):
    return torch.tensor([euler[2], euler[0], euler[1]])

def euler_zxy_to_xyz(euler):
    return torch.tensor([euler[1], euler[2], euler[0]])

print(roma.euler_to_unitquat('zxy', euler_xyz_to_zxy(torch.tensor([15, 22, -45])), degrees=True))
print(euler_zxy_to_xyz(roma.unitquat_to_euler('zxy', torch.tensor([0.04598, 0.22381, -0.39545, 0.88962]), degrees=True)))
# Out:
# tensor([ 0.0460,  0.2238, -0.3954,  0.8896])
# tensor([ 14.9999,  22.0000, -45.0000])

# %%
def angle_normalize(angle):
    return (angle + 180) % 360 - 180

def euler_normalize(euler):
    # Normalize each axis to be between -180 and 180
    return torch.tensor([angle_normalize(euler[0]), angle_normalize(euler[1]), angle_normalize(euler[2])])

def get_camera_position_and_rotation(character_pos, character_rot_y, camera_pos, camera_rot, distance):
    convention = 'zxy'
    character_rot = torch.tensor([0.0, character_rot_y, 0.0])
    camera_rot[1] = -camera_rot[1]
    
    character_rotation = roma.euler_to_unitquat(convention, euler_xyz_to_zxy(character_rot), degrees=True)
    print("character_rotation", character_rotation)
    local_camera_rotation = roma.euler_to_unitquat(convention, euler_xyz_to_zxy(camera_rot), degrees=True)
    print("local_camera_rotation", local_camera_rotation)
    extra_rotation = roma.euler_to_unitquat(convention, euler_xyz_to_zxy(torch.tensor([0.0, 180, 0.0])), degrees=True)
    
    combined_rotation = roma.quat_product(roma.quat_product(character_rotation, local_camera_rotation), extra_rotation)
    print("combined_rotation", combined_rotation)
    
    world_camera_pos = character_pos + roma.quat_action(character_rotation, camera_pos)
    print("world_camera_pos", world_camera_pos)
    camera_backward = roma.quat_action(combined_rotation, torch.tensor([0.0, 0.0, -distance]))
    print("camera_backward", camera_backward)
    final_camera_position = world_camera_pos + camera_backward
    print("final_camera_position", final_camera_position)
    
    final_camera_rotation = euler_zxy_to_xyz(roma.unitquat_to_euler(convention, combined_rotation, degrees=True))
    print("final_camera_rotation", final_camera_rotation)
    
    return final_camera_position, final_camera_rotation

character_pos = torch.tensor([0.5, 0, -0.5])
character_rot_y = 160
camera_pos = torch.tensor([1, 2, -0.8])
camera_rot = torch.tensor([10, 20, 45])
camera_distance = 2

get_camera_position_and_rotation(character_pos, character_rot_y, camera_pos, camera_rot, camera_distance)
# Out:
# character_rotation tensor([0.0000, 0.9848, 0.0000, 0.1736])
# local_camera_rotation tensor([ 0.0131, -0.1927,  0.3894,  0.9006])
# combined_rotation tensor([-0.0547,  0.3461,  0.3858, -0.8535])
# world_camera_pos tensor([-0.7133,  2.0000, -0.0903])
# camera_backward tensor([ 1.2660, -0.3473, -1.5088])
# final_camera_position tensor([ 0.5527,  1.6527, -1.5991])
# final_camera_rotation tensor([-10.0000, -40.0000, -45.0000])
# (tensor([ 0.5527,  1.6527, -1.5991]), tensor([-10.0000, -40.0000, -45.0000]))

# %%
# Load test cases
import json
with open("test_cases.json", "r") as f:
    test_cases = json.load(f)

def vector3_to_tensor(vector):
    return torch.tensor([vector['x'], vector['y'], vector['z']], dtype=torch.float32)

# Run test cases
for i, test_case in enumerate(test_cases):
    character_pos = vector3_to_tensor(test_case["characterPos"])
    character_rot_y = test_case["characterRotY"]
    camera_pos = vector3_to_tensor(test_case["cameraPos"])
    camera_rot = vector3_to_tensor(test_case["cameraRot"])
    distance = test_case["cameraDistance"]
    expected_pos = vector3_to_tensor(test_case["pos"])
    expected_rot = vector3_to_tensor(test_case["rot"])
    
    pos, rot = get_camera_position_and_rotation(character_pos, character_rot_y, camera_pos, camera_rot, distance)
    assert torch.allclose(pos, expected_pos, atol=1e-3), f"Test case {i + 1} failed, pos expected {expected_pos}, got {pos}"
    assert torch.allclose(euler_normalize(rot), euler_normalize(expected_rot), atol=1e-3), f"Test case {i + 1} failed, rot expected {expected_rot}, got {rot}"
    print(f"Test case {i+1} passed")
# Out:
# character_rotation tensor([0.0000, 0.2665, 0.0000, 0.9638])
# local_camera_rotation tensor([ 0.2988, -0.5251,  0.7451,  0.2827])
# combined_rotation tensor([-0.6385,  0.4124,  0.4865,  0.4307])
# world_camera_pos tensor([-3.4904, -9.1749, -1.7670])
# camera_backward tensor([ 1.8102, -6.4727,  1.0583])
# final_camera_position tensor([ -1.6802, -15.6476,  -0.7087])
# final_camera_rotation tensor([ -72.0501, -120.3119, -159.5769])
# Test case 1 passed
# character_rotation tensor([0.0000, 0.3016, 0.0000, 0.9534])
# local_camera_rotation tensor([ 0.2662, -0.4347,  0.8243,  0.2464])
# combined_rotation tensor([-0.7056,  0.3660,  0.5024,  0.3402])
# world_camera_pos tensor([-3.6586, -9.4851, -1.9613])
# camera_backward tensor([ 3.3042, -6.0900,  1.8949])
# final_camera_position tensor([ -0.3545, -15.5751,  -0.0664])
# final_camera_rotation tensor([ -57.9762, -119.8336, -160.7551])
# Test case 2 passed
# character_rotation tensor([0.0000, 0.3362, 0.0000, 0.9418])
# local_camera_rotation tensor([ 0.2274, -0.3358,  0.8893,  0.2115])
# combined_rotation tensor([-0.7611,  0.3121,  0.5131,  0.2452])
# world_camera_pos tensor([-3.8547, -9.7953, -2.0871])
# camera_backward tensor([ 4.7491, -5.2438,  2.6711])
# final_camera_position tensor([  0.8944, -15.0391,   0.5839])
# final_camera_rotation tensor([ -43.9023, -119.3552, -161.9332])
# Test case 3 passed
# character_rotation tensor([0.0000, 0.3704, 0.0000, 0.9289])
# local_camera_rotation tensor([ 0.1839, -0.2298,  0.9387,  0.1793])
# combined_rotation tensor([-0.8038,  0.2516,  0.5186,  0.1471])
# world_camera_pos tensor([ -4.0714, -10.1056,  -2.1430])
# camera_backward tensor([ 6.0326, -3.9500,  3.3270])
# final_camera_position tensor([  1.9612, -14.0556,   1.1840])
# final_camera_rotation tensor([ -29.8283, -118.8768, -163.1114])
# Test case 4 passed
# character_rotation tensor([0.0000, 0.4041, 0.0000, 0.9147])
# local_camera_rotation tensor([ 0.1376, -0.1183,  0.9718,  0.1508])
# combined_rotation tensor([-0.8333,  0.1858,  0.5186,  0.0473])
# world_camera_pos tensor([ -4.3013, -10.4158,  -2.1280])
# camera_backward tensor([ 7.0441, -2.2591,  3.8085])
# final_camera_position tensor([  2.7428, -12.6749,   1.6805])
# final_camera_rotation tensor([ -15.7544, -118.3985, -164.2895])
# Test case 5 passed
# character_rotation tensor([0.0000, 0.4373, 0.0000, 0.8993])
# local_camera_rotation tensor([ 0.0902, -0.0032,  0.9878,  0.1273])
# combined_rotation tensor([-0.8489,  0.1159,  0.5130, -0.0527])
# world_camera_pos tensor([ -4.5374, -10.7261,  -2.0420])
# camera_backward tensor([ 7.6835, -0.2551,  4.0717])
# final_camera_position tensor([  3.1462, -10.9812,   2.0297])
# final_camera_rotation tensor([  -1.6805, -117.9201, -165.4677])
# Test case 6 passed
# character_rotation tensor([0.0000, 0.4699, 0.0000, 0.8827])
# local_camera_rotation tensor([0.0435, 0.1136, 0.9865, 0.1093])
# combined_rotation tensor([-0.8504,  0.0431,  0.5019, -0.1516])
# world_camera_pos tensor([ -4.7722, -11.0363,  -1.8854])
# camera_backward tensor([7.8693, 1.9485, 4.0863])
# final_camera_position tensor([ 3.0971, -9.0878,  2.2010])
# final_camera_rotation tensor([  12.3935, -117.4418, -166.6458])
# Test case 7 passed
# character_rotation tensor([0.0000, 0.5018, 0.0000, 0.8650])
# local_camera_rotation tensor([-6.5962e-04,  2.3008e-01,  9.6826e-01,  9.7656e-02])
# combined_rotation tensor([-0.8378, -0.0310,  0.4853, -0.2480])
# world_camera_pos tensor([ -4.9987, -11.3466,  -1.6593])
# camera_backward tensor([7.5461, 4.2152, 3.8388])
# final_camera_position tensor([ 2.5473, -7.1314,  2.1795])
# final_camera_rotation tensor([  26.4674, -116.9634, -167.8240])
# Test case 8 passed
# character_rotation tensor([0.0000, 0.5331, 0.0000, 0.8461])
# local_camera_rotation tensor([-0.0407,  0.3441,  0.9335,  0.0926])
# combined_rotation tensor([-0.8114, -0.1051,  0.4632, -0.3405])
# world_camera_pos tensor([ -5.2101, -11.6568,  -1.3657])
# camera_backward tensor([6.6908, 6.3939, 3.3337])
# final_camera_position tensor([ 1.4807, -5.2629,  1.9681])
# final_camera_rotation tensor([  40.5413, -116.4851, -169.0022])
# Test case 9 passed
# character_rotation tensor([0.0000, 0.5637, 0.0000, 0.8260])
# local_camera_rotation tensor([-0.0750,  0.4536,  0.8830,  0.0944])
# combined_rotation tensor([-0.7716, -0.1777,  0.4358, -0.4279])
# world_camera_pos tensor([ -5.3995, -11.9671,  -1.0069])
# camera_backward tensor([5.3167, 8.3288, 2.5939])
# final_camera_position tensor([-0.0828, -3.6382,  1.5870])
# final_camera_rotation tensor([  54.6153, -116.0068, -170.1803])
# Test case 10 passed
# character_rotation tensor([0.0000, 0.4761, 0.0000, 0.8794])
# local_camera_rotation tensor([ 0.6873, -0.3860,  0.0772,  0.6105])
# combined_rotation tensor([0.2593, 0.7206, 0.6412, 0.0488])
# world_camera_pos tensor([-14.8162,  -3.0497,   7.8790])
# camera_backward tensor([-2.2675, -5.0590,  0.9742])
# final_camera_position tensor([-17.0837,  -8.1088,   8.8532])
# final_camera_rotation tensor([-63.9961, 113.2507,  84.3275])
# Test case 11 passed
# character_rotation tensor([0.0000, 0.3845, 0.0000, 0.9231])
# local_camera_rotation tensor([ 0.6775, -0.3600,  0.0099,  0.6414])
# combined_rotation tensor([0.2513, 0.7305, 0.6292, 0.0857])
# world_camera_pos tensor([-14.2249,  -2.1218,   6.7026])
# camera_backward tensor([-2.8699, -5.6949,  1.2583])
# final_camera_position tensor([-17.0948,  -7.8168,   7.9609])
# final_camera_rotation tensor([-61.1782, 113.6750,  80.2158])
# Test case 12 passed
# character_rotation tensor([0.0000, 0.2889, 0.0000, 0.9574])
# local_camera_rotation tensor([ 0.6588, -0.3304, -0.0548,  0.6736])
# combined_rotation tensor([0.2428, 0.7404, 0.6149, 0.1218])
# world_camera_pos tensor([-13.2878,  -1.1939,   5.8531])
# camera_backward tensor([-3.5298, -6.2757,  1.5789])
# final_camera_position tensor([-16.8176,  -7.4697,   7.4320])
# final_camera_rotation tensor([-58.3604, 114.0993,  76.1041])
# Test case 13 passed
# character_rotation tensor([0.0000, 0.1903, 0.0000, 0.9817])
# local_camera_rotation tensor([ 0.6318, -0.2967, -0.1155,  0.7067])
# combined_rotation tensor([0.2336, 0.7502, 0.5983, 0.1568])
# world_camera_pos tensor([-12.1086,  -0.2660,   5.3889])
# camera_backward tensor([-4.2429, -6.7965,  1.9357])
# final_camera_position tensor([-16.3515,  -7.0625,   7.3246])
# final_camera_rotation tensor([-55.5425, 114.5236,  71.9923])
# Test case 14 passed
# character_rotation tensor([0.0000, 0.0897, 0.0000, 0.9960])
# local_camera_rotation tensor([ 0.5973, -0.2581, -0.1708,  0.7399])
# combined_rotation tensor([0.2237, 0.7601, 0.5796, 0.1906])
# world_camera_pos tensor([-10.7988,   0.6619,   5.3403])
# camera_backward tensor([-5.0048, -7.2523,  2.3282])
# final_camera_position tensor([-15.8036,  -6.5904,   7.6685])
# final_camera_rotation tensor([-52.7247, 114.9479,  67.8806])
# Test case 15 passed
# character_rotation tensor([ 0.0000, -0.0118,  0.0000,  0.9999])
# local_camera_rotation tensor([ 0.5562, -0.2141, -0.2198,  0.7723])
# combined_rotation tensor([0.2132, 0.7697, 0.5587, 0.2232])
# world_camera_pos tensor([-9.4713,  1.5898,  5.7090])
# camera_backward tensor([-5.8105, -7.6386,  2.7556])
# final_camera_position tensor([-15.2817,  -6.0488,   8.4646])
# final_camera_rotation tensor([-49.9068, 115.3722,  63.7689])
# Test case 16 passed
# character_rotation tensor([ 0.0000, -0.1131,  0.0000,  0.9936])
# local_camera_rotation tensor([ 0.5096, -0.1645, -0.2615,  0.8031])
# combined_rotation tensor([0.2021, 0.7793, 0.5359, 0.2543])
# world_camera_pos tensor([-8.2329,  2.5177,  6.4688])
# camera_backward tensor([-6.6551, -7.9514,  3.2167])
# final_camera_position tensor([-14.8880,  -5.4337,   9.6855])
# final_camera_rotation tensor([-47.0890, 115.7965,  59.6571])
# Test case 17 passed
# character_rotation tensor([ 0.0000, -0.2133,  0.0000,  0.9770])
# local_camera_rotation tensor([ 0.4587, -0.1091, -0.2950,  0.8311])
# combined_rotation tensor([0.1903, 0.7886, 0.5111, 0.2839])
# world_camera_pos tensor([-7.1784,  3.4456,  7.5684])
# camera_backward tensor([-7.5334, -8.1866,  3.7103])
# final_camera_position tensor([-14.7118,  -4.7409,  11.2788])
# final_camera_rotation tensor([-44.2711, 116.2209,  55.5454])
# Test case 18 passed
# character_rotation tensor([ 0.0000, -0.3113,  0.0000,  0.9503])
# local_camera_rotation tensor([ 0.4050, -0.0480, -0.3199,  0.8552])
# combined_rotation tensor([0.1779, 0.7977, 0.4845, 0.3118])
# world_camera_pos tensor([-6.3848,  4.3735,  8.9355])
# camera_backward tensor([-8.4400, -8.3406,  4.2348])
# final_camera_position tensor([-14.8248,  -3.9671,  13.1703])
# final_camera_rotation tensor([-41.4533, 116.6452,  51.4336])
# Test case 19 passed
# character_rotation tensor([ 0.0000, -0.4061,  0.0000,  0.9138])
# local_camera_rotation tensor([ 0.3499,  0.0187, -0.3359,  0.8743])
# combined_rotation tensor([0.1649, 0.8066, 0.4561, 0.3379])
# world_camera_pos tensor([-5.9069,  5.3015, 10.4818])
# camera_backward tensor([-9.3694, -8.4103,  4.7883])
# final_camera_position tensor([-15.2763,  -3.1088,  15.2701])
# final_camera_rotation tensor([-38.6354, 117.0695,  47.3219])
# Test case 20 passed
# character_rotation tensor([ 0.0000, -0.7316,  0.0000,  0.6818])
# local_camera_rotation tensor([ 0.0668,  0.4886,  0.8288, -0.2643])
# combined_rotation tensor([-0.6140,  0.1772, -0.5608, -0.5265])
# world_camera_pos tensor([-9.0274, 10.1033, -4.7948])
# camera_backward tensor([-0.8190,  1.3788, -0.2989])
# final_camera_position tensor([-9.8464, 11.4821, -5.0937])
# final_camera_rotation tensor([ 57.6948,  69.9479, 135.7615])
# Test case 21 passed
# character_rotation tensor([ 0.0000, -0.6921,  0.0000,  0.7218])
# local_camera_rotation tensor([ 5.2828e-04,  4.9546e-01,  8.5172e-01, -1.7057e-01])
# combined_rotation tensor([-0.6151,  0.2198, -0.5891, -0.4757])
# world_camera_pos tensor([-9.0576, 10.0053, -4.5987])
# camera_backward tensor([-1.3073,  2.1402, -0.3717])
# final_camera_position tensor([-10.3649,  12.1454,  -4.9704])
# final_camera_rotation tensor([ 57.5823,  74.1276, 147.2463])
# Test case 22 passed
# character_rotation tensor([ 0.0000, -0.6505,  0.0000,  0.7595])
# local_camera_rotation tensor([-0.0663,  0.4938,  0.8638, -0.0750])
# combined_rotation tensor([-0.6129,  0.2642, -0.6123, -0.4238])
# world_camera_pos tensor([-8.9903,  9.9073, -4.2613])
# camera_backward tensor([-1.8110,  2.8996, -0.3748])
# final_camera_position tensor([-10.8013,  12.8068,  -4.6361])
# final_camera_rotation tensor([ 57.4698,  78.3072, 158.7311])
# Test case 23 passed
# character_rotation tensor([ 0.0000, -0.6068,  0.0000,  0.7948])
# local_camera_rotation tensor([-0.1326,  0.4835,  0.8650,  0.0211])
# combined_rotation tensor([-0.6071,  0.3102, -0.6303, -0.3715])
# world_camera_pos tensor([-8.8039,  9.8092, -3.7998])
# camera_backward tensor([-2.3225,  3.6571, -0.3063])
# final_camera_position tensor([-11.1265,  13.4663,  -4.1062])
# final_camera_rotation tensor([ 57.3573,  82.4868, 170.2159])
# Test case 24 passed
# character_rotation tensor([ 0.0000, -0.5612,  0.0000,  0.8277])
# local_camera_rotation tensor([-0.1973,  0.4648,  0.8553,  0.1166])
# combined_rotation tensor([-0.5971,  0.3573, -0.6433, -0.3192])
# world_camera_pos tensor([-8.4799,  9.7112, -3.2347])
# camera_backward tensor([-2.8341,  4.4127, -0.1651])
# final_camera_position tensor([-11.3140,  14.1239,  -3.3997])
# final_camera_rotation tensor([  57.2448,   86.6665, -178.2993])
# Test case 25 passed
# character_rotation tensor([ 0.0000, -0.5139,  0.0000,  0.8579])
# local_camera_rotation tensor([-0.2593,  0.4378,  0.8348,  0.2101])
# combined_rotation tensor([-0.5829,  0.4052, -0.6515, -0.2676])
# world_camera_pos tensor([-8.0024,  9.6132, -2.5885])
# camera_backward tensor([-3.3377,  5.1663,  0.0493])
# final_camera_position tensor([-11.3401,  14.7795,  -2.5392])
# final_camera_rotation tensor([  57.1322,   90.8461, -166.8145])
# Test case 26 passed
# character_rotation tensor([ 0.0000, -0.4649,  0.0000,  0.8854])
# local_camera_rotation tensor([-0.3177,  0.4029,  0.8040,  0.3005])
# combined_rotation tensor([-0.5642,  0.4534, -0.6550, -0.2171])
# world_camera_pos tensor([-7.3592,  9.5152, -1.8863])
# camera_backward tensor([-3.8255,  5.9180,  0.3364])
# final_camera_position tensor([-11.1848,  15.4332,  -1.5498])
# final_camera_rotation tensor([  57.0197,   95.0257, -155.3297])
# Test case 27 passed
# character_rotation tensor([ 0.0000, -0.4144,  0.0000,  0.9101])
# local_camera_rotation tensor([-0.3713,  0.3608,  0.7632,  0.3866])
# combined_rotation tensor([-0.5407,  0.5013, -0.6543, -0.1681])
# world_camera_pos tensor([-6.5419,  9.4171, -1.1545])
# camera_backward tensor([-4.2895,  6.6677,  0.6952])
# final_camera_position tensor([-10.8314,  16.0849,  -0.4594])
# final_camera_rotation tensor([  56.9072,   99.2054, -143.8449])
# Test case 28 passed
# character_rotation tensor([ 0.0000, -0.3627,  0.0000,  0.9319])
# local_camera_rotation tensor([-0.4195,  0.3118,  0.7131,  0.4672])
# combined_rotation tensor([-0.5124,  0.5485, -0.6496, -0.1212])
# world_camera_pos tensor([-5.5457,  9.3191, -0.4210])
# camera_backward tensor([-4.7217,  7.4155,  1.1236])
# final_camera_position tensor([-10.2674,  16.7346,   0.7026])
# final_camera_rotation tensor([  56.7947,  103.3851, -132.3601])
# Test case 29 passed
# character_rotation tensor([ 0.0000, -0.3098,  0.0000,  0.9508])
# local_camera_rotation tensor([-0.4613,  0.2569,  0.6543,  0.5414])
# combined_rotation tensor([-0.4793,  0.5943, -0.6413, -0.0766])
# world_camera_pos tensor([-4.3701,  9.2211,  0.2862])
# camera_backward tensor([-5.1145,  8.1613,  1.6189])
# final_camera_position tensor([-9.4846, 17.3824,  1.9052])
# final_camera_rotation tensor([  56.6822,  107.5647, -120.8753])
# Test case 30 passed
# character_rotation tensor([0.0000, 0.0669, 0.0000, 0.9978])
# local_camera_rotation tensor([-0.6125,  0.3480,  0.4451,  0.5528])
# combined_rotation tensor([-0.4851,  0.5283, -0.5813, -0.3842])
# world_camera_pos tensor([ 11.4296,  16.0506, -15.0695])
# camera_backward tensor([-0.4657,  2.9088,  0.0851])
# final_camera_position tensor([ 10.9638,  18.9594, -14.9844])
# final_camera_rotation tensor([  80.7553,  100.3531, -155.7955])
# Test case 31 passed
# character_rotation tensor([0.0000, 0.0749, 0.0000, 0.9972])
# local_camera_rotation tensor([-0.5768,  0.4058,  0.3731,  0.6028])
# combined_rotation tensor([-0.4153,  0.5707, -0.5473, -0.4498])
# world_camera_pos tensor([ 12.0082,  15.9268, -13.9354])
# camera_backward tensor([ 0.2001,  3.3903, -0.0124])
# final_camera_position tensor([ 12.2083,  19.3171, -13.9478])
# final_camera_rotation tensor([ 86.6165, -86.4510,  18.0832])
# Test case 32 passed
# character_rotation tensor([0.0000, 0.0829, 0.0000, 0.9966])
# local_camera_rotation tensor([-0.5196,  0.4467,  0.3085,  0.6598])
# combined_rotation tensor([-0.3505,  0.6205, -0.4922, -0.4999])
# world_camera_pos tensor([ 12.6116,  15.8031, -12.8332])
# camera_backward tensor([1.0590, 3.6961, 0.0602])
# final_camera_position tensor([ 13.6706,  19.4992, -12.7730])
# final_camera_rotation tensor([ 73.9884, -93.2552,  11.9619])
# Test case 33 passed
# character_rotation tensor([0.0000, 0.0910, 0.0000, 0.9959])
# local_camera_rotation tensor([-0.4437,  0.4682,  0.2545,  0.7205])
# combined_rotation tensor([-0.2938,  0.6750, -0.4187, -0.5318])
# world_camera_pos tensor([ 13.2389,  15.6794, -11.7634])
# camera_backward tensor([2.0267, 3.7690, 0.3595])
# final_camera_position tensor([ 15.2656,  19.4484, -11.4038])
# final_camera_rotation tensor([  61.3602, -100.0594,    5.8406])
# Test case 34 passed
# character_rotation tensor([0.0000, 0.0990, 0.0000, 0.9951])
# local_camera_rotation tensor([-0.3529,  0.4685,  0.2137,  0.7812])
# combined_rotation tensor([-0.2476,  0.7310, -0.3300, -0.5435])
# world_camera_pos tensor([ 13.8893,  15.5556, -10.7265])
# camera_backward tensor([2.9942, 3.5654, 0.9076])
# final_camera_position tensor([16.8836, 19.1210, -9.8189])
# final_camera_rotation tensor([  48.7320, -106.8636,   -0.2807])
# Test case 35 passed
# character_rotation tensor([0.0000, 0.1071, 0.0000, 0.9943])
# local_camera_rotation tensor([-0.2515,  0.4467,  0.1879,  0.8378])
# combined_rotation tensor([-0.2137,  0.7852, -0.2299, -0.5338])
# world_camera_pos tensor([14.5620, 15.4319, -9.7232])
# camera_backward tensor([3.8426, 3.0598, 1.6842])
# final_camera_position tensor([18.4046, 18.4917, -8.0390])
# final_camera_rotation tensor([  36.1039, -113.6678,   -6.4019])
# Test case 36 passed
# character_rotation tensor([0.0000, 0.1151, 0.0000, 0.9934])
# local_camera_rotation tensor([-0.1439,  0.4031,  0.1777,  0.8861])
# combined_rotation tensor([-0.1931,  0.8338, -0.1225, -0.5024])
# world_camera_pos tensor([15.2562, 15.3082, -8.7541])
# camera_backward tensor([4.4601, 2.2475, 2.6242])
# final_camera_position tensor([19.7163, 17.5556, -6.1298])
# final_camera_rotation tensor([  23.4757, -120.4719,  -12.5232])
# Test case 37 passed
# character_rotation tensor([0.0000, 0.1231, 0.0000, 0.9924])
# local_camera_rotation tensor([-0.0348,  0.3390,  0.1830,  0.9222])
# combined_rotation tensor([-0.1859,  0.8734, -0.0120, -0.4499])
# world_camera_pos tensor([15.9710, 15.1844, -7.8196])
# camera_backward tensor([4.7601, 1.1463, 3.6231])
# final_camera_position tensor([20.7311, 16.3307, -4.1965])
# final_camera_rotation tensor([  10.8475, -127.2761,  -18.6445])
# Test case 38 passed
# character_rotation tensor([0.0000, 0.1311, 0.0000, 0.9914])
# local_camera_rotation tensor([0.0717, 0.2566, 0.2027, 0.9423])
# combined_rotation tensor([-0.1915,  0.9005,  0.0976, -0.3779])
# world_camera_pos tensor([16.7056, 15.0607, -6.9202])
# camera_backward tensor([ 4.6959, -0.2032,  4.5475])
# final_camera_position tensor([21.4015, 14.8575, -2.3727])
# final_camera_rotation tensor([  -1.7806, -134.0802,  -24.7658])
# Test case 39 passed
# character_rotation tensor([0.0000, 0.1391, 0.0000, 0.9903])
# local_camera_rotation tensor([0.1714, 0.1590, 0.2346, 0.9436])
# combined_rotation tensor([-0.2085,  0.9123,  0.2023, -0.2887])
# world_camera_pos tensor([17.4591, 14.9369, -6.0566])
# camera_backward tensor([ 4.2707, -1.7392,  5.2522])
# final_camera_position tensor([21.7298, 13.1978, -0.8044])
# final_camera_rotation tensor([ -14.4088, -140.8844,  -30.8870])
# Test case 40 passed
# character_rotation tensor([ 0.0000, -0.1832,  0.0000,  0.9831])
# local_camera_rotation tensor([-0.2347, -0.6635, -0.6579,  0.2680])
# combined_rotation tensor([ 0.6897,  0.1419, -0.1103,  0.7014])
# world_camera_pos tensor([ -4.6730, -17.8489, -11.8549])
# camera_backward tensor([-0.2425,  5.1586, -0.0425])
# final_camera_position tensor([ -4.9155, -12.6903, -11.8974])
# final_camera_rotation tensor([87.2672, 80.0670, 59.5176])
# Test case 41 passed
# character_rotation tensor([ 0.0000, -0.0991,  0.0000,  0.9951])
# local_camera_rotation tensor([ 0.0051, -0.7153, -0.6828,  0.1487])
# combined_rotation tensor([0.6789, 0.0770, 0.0727, 0.7265])
# world_camera_pos tensor([ -5.6924, -17.6711, -12.7550])
# camera_backward tensor([-1.1889,  5.5033, -0.3740])
# final_camera_position tensor([ -6.8813, -12.1678, -13.1290])
# final_camera_rotation tensor([77.2399, 72.5391, 72.1885])
# Test case 42 passed
# character_rotation tensor([ 0.0000, -0.0144,  0.0000,  0.9999])
# local_camera_rotation tensor([ 0.2450, -0.7188, -0.6501,  0.0258])
# combined_rotation tensor([0.6465, 0.0154, 0.2544, 0.7191])
# world_camera_pos tensor([ -6.7238, -17.4934, -13.6778])
# camera_backward tensor([-2.1488,  5.6432, -1.0015])
# final_camera_position tensor([ -8.8726, -11.8502, -14.6793])
# final_camera_rotation tensor([67.2126, 65.0111, 84.8594])
# Test case 43 passed
# character_rotation tensor([0.0000, 0.0705, 0.0000, 0.9975])
# local_camera_rotation tensor([ 0.4681, -0.6762, -0.5625, -0.0851])
# combined_rotation tensor([ 0.5941, -0.0373,  0.4273,  0.6805])
# world_camera_pos tensor([ -7.7846, -17.3156, -14.6198])
# camera_backward tensor([-3.0156,  5.5462, -1.9224])
# final_camera_position tensor([-10.8002, -11.7695, -16.5422])
# final_camera_rotation tensor([57.1854, 57.4832, 97.5303])
# Test case 44 passed
# character_rotation tensor([0.0000, 0.1548, 0.0000, 0.9879])
# local_camera_rotation tensor([ 0.6590, -0.5947, -0.4280, -0.1701])
# combined_rotation tensor([ 0.5249, -0.0760,  0.5847,  0.6139])
# world_camera_pos tensor([ -8.8911, -17.1379, -15.5722])
# camera_backward tensor([-3.6842,  5.1894, -3.0963])
# final_camera_position tensor([-12.5752, -11.9485, -18.6685])
# final_camera_rotation tensor([ 47.1581,  49.9553, 110.2012])
# Test case 45 passed
# character_rotation tensor([0.0000, 0.2381, 0.0000, 0.9712])
# local_camera_rotation tensor([ 0.8059, -0.4857, -0.2588, -0.2186])
# combined_rotation tensor([ 0.4432, -0.0967,  0.7211,  0.5237])
# world_camera_pos tensor([-10.0571, -16.9602, -16.5214])
# camera_backward tensor([-4.0640,  4.5609, -4.4464])
# final_camera_position tensor([-14.1211, -12.3993, -20.9678])
# final_camera_rotation tensor([ 37.1309,  42.4274, 122.8721])
# Test case 46 passed
# character_rotation tensor([0.0000, 0.3196, 0.0000, 0.9476])
# local_camera_rotation tensor([ 0.9016, -0.3632, -0.0700, -0.2245])
# combined_rotation tensor([ 0.3544, -0.0966,  0.8319,  0.4159])
# world_camera_pos tensor([-11.2927, -16.7824, -17.4496])
# camera_backward tensor([-4.0918,  3.6603, -5.8655])
# final_camera_position tensor([-15.3845, -13.1221, -23.3151])
# final_camera_rotation tensor([ 27.1036,  34.8995, 135.5430])
# Test case 47 passed
# character_rotation tensor([0.0000, 0.3988, 0.0000, 0.9170])
# local_camera_rotation tensor([ 0.9441, -0.2425,  0.1221, -0.1869])
# combined_rotation tensor([ 0.2645, -0.0747,  0.9145,  0.2969])
# world_camera_pos tensor([-12.6035, -16.6047, -18.3357])
# camera_backward tensor([-3.7410,  2.4996, -7.2260])
# final_camera_position tensor([-16.3445, -14.1051, -25.5617])
# final_camera_rotation tensor([ 17.0763,  27.3715, 148.2139])
# Test case 48 passed
# character_rotation tensor([0.0000, 0.4752, 0.0000, 0.8799])
# local_camera_rotation tensor([ 0.9369, -0.1380,  0.3018, -0.1100])
# combined_rotation tensor([ 0.1796, -0.0312,  0.9678,  0.1737])
# world_camera_pos tensor([-13.9895, -16.4270, -19.1564])
# camera_backward tensor([-3.0288,  1.1033, -8.3927])
# final_camera_position tensor([-17.0183, -15.3237, -27.5491])
# final_camera_rotation tensor([  7.0491,  19.8436, 160.8848])
# Test case 49 passed
# character_rotation tensor([0.0000, 0.5481, 0.0000, 0.8364])
# local_camera_rotation tensor([ 0.8880, -0.0618,  0.4556, -0.0025])
# combined_rotation tensor([0.1056, 0.0318, 0.9925, 0.0531])
# world_camera_pos tensor([-15.4449, -16.2492, -19.8874])
# camera_backward tensor([-2.0169, -0.4920, -9.2383])
# final_camera_position tensor([-17.4618, -16.7412, -29.1257])
# final_camera_rotation tensor([ -2.9782,  12.3157, 173.5557])
# Test case 50 passed
